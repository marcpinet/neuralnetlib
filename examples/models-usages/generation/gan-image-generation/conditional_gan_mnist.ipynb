# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import os

from PIL import Image
from keras.datasets import mnist
from IPython.display import Image as IPImage

from neuralnetlib.preprocessing import one_hot_encode
from neuralnetlib.models import Sequential, GAN
from neuralnetlib.layers import Input, Dense, BatchNormalization, Dropout
from neuralnetlib.optimizers import Adam

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
n_classes = np.unique(y_train).shape[0]

# Concatenate train and test data
X = np.concatenate([x_train, x_test])
y = np.concatenate([y_train, y_test])

# Flatten images
X = X.reshape(X.shape[0], -1)

# Normalize pixel values
X = X.astype('float32') / 255

# Labels to categorical 
y = one_hot_encode(y, n_classes)

# %%
i = random.randint(0,len(X) - 1)
plt.imshow(X[i].reshape(28,28), cmap='gray')
plt.title('Class: ' + str(np.argmax(y[i])))
plt.show()

# %%
noise_dim = 100

generator = Sequential()
generator.add(Input(noise_dim + n_classes))
generator.add(Dense(256, activation='leakyrelu'))
generator.add(BatchNormalization())
generator.add(Dense(512, activation='leakyrelu'))
generator.add(BatchNormalization())
generator.add(Dense(1024, activation='leakyrelu'))
generator.add(BatchNormalization())
generator.add(Dense(784, activation='sigmoid'))

# %%
discriminator = Sequential()
discriminator.add(Input(784 + n_classes))
discriminator.add(Dense(1024, activation='leakyrelu'))
discriminator.add(Dropout(0.3))
discriminator.add(Dense(512, activation='leakyrelu'))
discriminator.add(Dropout(0.3))
discriminator.add(Dense(256, activation='leakyrelu'))
discriminator.add(Dropout(0.3))
discriminator.add(Dense(1, activation='sigmoid'))

# %%
gan = GAN(latent_dim=noise_dim, n_classes=n_classes)

gan.compile(
    generator,
    discriminator,
    generator_optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    discriminator_optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    loss_function='bce',
    verbose=True
)
# Out:
# Inferred image dimensions: 28x28
# GAN(latent_dim=100, gradient_clip_threshold=0.1, enable_padding=False, padding_size=32, random_state=1733822707195075100)
# -------------------------------------------------
# Generator:
# Sequential(gradient_clip_threshold=5.0, enable_padding=False, padding_size=32, random_state=1733822707163883200)
# -------------------------------------------------
# Layer 1: Input(input_shape=(110,))
# Layer 2: Dense(units=256)
# Layer 3: Activation(LeakyReLU)
# Layer 4: BatchNormalization(momentum=0.9, epsilon=1e-05)
# Layer 5: Dense(units=512)
# Layer 6: Activation(LeakyReLU)
# Layer 7: BatchNormalization(momentum=0.9, epsilon=1e-05)
# Layer 8: Dense(units=1024)
# Layer 9: Activation(LeakyReLU)
# Layer 10: BatchNormalization(momentum=0.9, epsilon=1e-05)
# Layer 11: Dense(units=784)
# Layer 12: Activation(Sigmoid)
# -------------------------------------------------
# Loss function: BinaryCrossentropy
# Optimizer: Adam(learning_rate=0.0002, beta_1=0.5, beta_2=0.999, epsilon=1e-08, clip_norm=None, clip_value=None)
# -------------------------------------------------
# -------------------------------------------------
# Discriminator:
# Sequential(gradient_clip_threshold=5.0, enable_padding=False, padding_size=32, random_state=1733822707179083700)
# -------------------------------------------------
# Layer 1: Input(input_shape=(794,))
# Layer 2: Dense(units=1024)
# Layer 3: Activation(LeakyReLU)
# Layer 4: Dropout(rate=0.3)
# Layer 5: Dense(units=512)
# Layer 6: Activation(LeakyReLU)
# Layer 7: Dropout(rate=0.3)
# Layer 8: Dense(units=256)
# Layer 9: Activation(LeakyReLU)
# Layer 10: Dropout(rate=0.3)
# Layer 11: Dense(units=1)
# Layer 12: Activation(Sigmoid)
# -------------------------------------------------
# Loss function: BinaryCrossentropy
# Optimizer: Adam(learning_rate=0.0002, beta_1=0.5, beta_2=0.999, epsilon=1e-08, clip_norm=None, clip_value=None)
# -------------------------------------------------

# %%
history = gan.fit(X,
                  y,
                 epochs=100,
                 batch_size=64,
                 plot_generated=True,
                 )
# Out:
# [===---------------------------] 12% Epoch 1/100 - d_loss: 0.3305 - g_loss: 1.9079 - mmd: 0.0 - 55.07s3e-10 - 54.54s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 history = gan.fit(X,
#       2                   y,
#       3                  epochs=100,
#       4                  batch_size=64,
#       5                  plot_generated=True,
#       6                  metrics=['mmd_score'],
#       7                  )
#
# File c:\users\marcp\documents\programming\python\neuralnetlib\neuralnetlib\models.py:2842, in GAN.fit(self, x_train, y_train, epochs, batch_size, n_critic, verbose, metrics, random_state, validation_data, validation_split, callbacks, plot_generated, plot_interval, fixed_noise, fixed_labels, n_gen_samples, visualization_grid)
#    2839 for callback in callbacks:
#    2840     callback.on_batch_begin(batch_index, batch_logs)
# -> 2842 d_loss, g_loss = self.train_on_batch(
#    2843     x_batch, y_batch, min(batch_size, len(x_batch)), n_critic)
#    2844 d_error += d_loss
#    2845 g_error += g_loss
#
# File c:\users\marcp\documents\programming\python\neuralnetlib\neuralnetlib\models.py:2681, in GAN.train_on_batch(self, real_samples, labels, batch_size, n_critic)
#    2679     d_loss = self.discriminator_loss(combined_labels, predictions)
#    2680     d_grad = self.discriminator_loss.derivative(combined_labels, predictions)
# -> 2681     self.discriminator.backward_pass(d_grad)
#    2683     d_loss_total += d_loss
#    2685 d_loss_avg = d_loss_total / n_critic
#
# File c:\users\marcp\documents\programming\python\neuralnetlib\neuralnetlib\models.py:222, in Sequential.backward_pass(self, error, gan, compute_only)
#     220 if hasattr(layer, 'd_bias'):
#     221     clipped_bias_grad = clip_gradients(layer.d_bias)
# --> 222     self.optimizer.update(layer_idx, layer.weights, clipped_weights_grad,
#     223                           layer.bias, clipped_bias_grad)
#     224 else:
#     225     self.optimizer.update(
#     226         layer_idx, layer.weights, clipped_weights_grad)
#
# File c:\users\marcp\documents\programming\python\neuralnetlib\neuralnetlib\optimizers.py:221, in Adam.update(self, layer_index, weights, weights_grad, bias, bias_grad)
#     217         self.v_b[layer_index] = np.zeros_like(bias)
#     219 self.t += 1
# --> 221 weights, self.m_w[layer_index], self.v_w[layer_index] = self._compute_moments(
#     222     weights, weights_grad, self.m_w[layer_index], self.v_w[layer_index]
#     223 )
#     225 if bias is not None and bias_grad is not None:
#     226     bias, self.m_b[layer_index], self.v_b[layer_index] = self._compute_moments(
#     227         bias, bias_grad, self.m_b[layer_index], self.v_b[layer_index]
#     228     )
#
# File c:\users\marcp\documents\programming\python\neuralnetlib\neuralnetlib\optimizers.py:194, in Adam._compute_moments(self, param, grad, m, v)
#     191 grad = self._clip_gradients(grad)
#     193 m = self.beta_1 * m + (1 - self.beta_1) * grad
# --> 194 v = self.beta_2 * v + (1 - self.beta_2) * np.square(grad)
#     196 beta1_t = self.beta_1 ** self.t
#     197 beta2_t = self.beta_2 ** self.t
#
# KeyboardInterrupt:

# %%
image_files = [f for f in os.listdir() if f.endswith('.png') and f.startswith('video')]
image_files.sort(key=lambda x: int(x.replace('video', '').replace('.png', '')))

images = [Image.open(img) for img in image_files]

if images:
    images[0].save('output_4.gif', save_all=True, append_images=images[1:], duration=100, loop=0)

print("GIF 'output.gif' succesffuly created!")
# Out:
# GIF 'output.gif' succesffuly created!

# %%
IPImage(filename="output_4.gif")

# %%
labels = np.array([9] * 10)  # we will generate the number 9
samples = gan.predict(n_samples=10, labels=labels)

plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.imshow(samples[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 labels = np.array([9] * 10)  # we will generate the number 9
#       2 samples = gan.predict(n_samples=10, labels=labels)
#       4 plt.figure(figsize=(20, 4))
#
# NameError: name 'np' is not defined
